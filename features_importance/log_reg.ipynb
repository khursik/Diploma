# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("data/with_avg_vals.csv")
df
# Out:
#                 1_1           1_2           1_3           1_4           1_5  \
# 0      2.148821e-12  1.762882e-12  1.459278e-13  1.587917e-13  8.052632e-14
# 1      1.270260e-12  8.164477e-13  5.903729e-13  3.056763e-13  1.406329e-13
# 2      7.709517e-13  1.717117e-13  3.039963e-13  1.663584e-13  1.726942e-13
# 3      2.800220e-12  3.611335e-13  9.828645e-13  3.723583e-13  1.130286e-13
# 4      9.507999e-13  4.833313e-13  1.694255e-12  1.434799e-13  1.543624e-13
# ...             ...           ...           ...           ...           ...
# 10638  2.783871e-12  4.492069e-13  6.107854e-13  2.169733e-13  2.887208e-13
# 10639  1.394714e-12  2.106615e-12  2.131392e-12  1.251115e-12  4.735738e-13
# 10640  3.272053e-12  2.410372e-12  3.519692e-12  3.088923e-13  4.243452e-13
# 10641  1.226257e-11  3.028533e-12  6.798046e-13  3.032247e-13  5.241077e-13
# 10642  8.328733e-11  2.666764e-12  6.353130e-12  8.844715e-13  2.507915e-13
#
# ...

# %%
X_train = df.iloc[::, :-2].values
y_train = df.task.values
model = LogisticRegression(random_state=0)
X_train, y_train
# Out:
# (array([[2.14882146e-12, 1.76288193e-12, 1.45927817e-13, ...,
#          4.65372520e-13, 6.21183933e-13, 8.28598977e-13],
#         [1.27025977e-12, 8.16447712e-13, 5.90372939e-13, ...,
#          1.51132961e-12, 1.07986456e-12, 2.84452204e-12],
#         [7.70951725e-13, 1.71711657e-13, 3.03996300e-13, ...,
#          1.50278851e-12, 1.40708017e-12, 4.51994176e-12],
#         ...,
#         [3.27205332e-12, 2.41037178e-12, 3.51969218e-12, ...,
#          6.60618938e-13, 3.93216955e-13, 6.88366626e-13],
#         [1.22625683e-11, 3.02853318e-12, 6.79804570e-13, ...,
#          3.45543541e-13, 5.68109652e-13, 6.36310290e-12],
#         [8.32873277e-11, 2.66676391e-12, 6.35313000e-12, ...,
#          1.19176555e-12, 9.10019667e-13, 1.18364981e-12]]),
#  array([0, 0, 0, ..., 3, 3, 3], dtype=int64))

# %%
#model.fit(X, y)

# %%
df_copy = df
uniq_val = np.unique(df.name.values)
def get_data_for_person(value: str) -> np.ndarray:
    X = df.loc[df.name == value].drop(['name', 'task'], axis=1)
    y = df.task.loc[df.name == value]
    return X, y


get_data_for_person("chcon_s_100")
# Out:
# (               1_1           1_2           1_3           1_4           1_5  \
#  0     2.148821e-12  1.762882e-12  1.459278e-13  1.587917e-13  8.052632e-14
#  1     1.270260e-12  8.164477e-13  5.903729e-13  3.056763e-13  1.406329e-13
#  2     7.709517e-13  1.717117e-13  3.039963e-13  1.663584e-13  1.726942e-13
#  3     2.800220e-12  3.611335e-13  9.828645e-13  3.723583e-13  1.130286e-13
#  4     9.507999e-13  4.833313e-13  1.694255e-12  1.434799e-13  1.543624e-13
#  ...            ...           ...           ...           ...           ...
#  7673  1.880686e-12  1.030432e-12  1.553474e-12  7.930886e-14  5.353515e-13
#  7674  2.150064e-12  6.892344e-13  2.096113e-13  2.722973e-13  1.754750e-13
#  7675  6.823090e-13  7.537357e-13  4.209751e-13  5.989283e-13  1.009683e-13
#  7676  9.107563e-12  1.288950e-12  7.865605e-13  4.031002e-13  1.670217e-13
#  7677  3.154460e-12  1.496342e-12  2.046483e-13  3.089252e-13  2.466356e-13
#
# ...
